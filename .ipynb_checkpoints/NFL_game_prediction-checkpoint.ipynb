# %% [markdown]
# # CS 254 Machine Learning Final Project
#
# We will be using the ***NFL scores and betting data*** dataset to analyze successful betting techniques and winning strategies.
#
# ### Overview
#
# 1. Import packages
# 2. Wrangle and clean
# 3. Explore data
# 4. Classify and predict
# ---

# %% [markdown]
# ### Part 1 (Import Packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
# %matplotlib inline
#List of imports will get longer

# %% [markdown]
# ### Part 2 *(Wrangle and clean)*

# %%
data = pd.read_csv("nfl-scores-and-betting-data/spreadspoke_scores.csv")
teams = pd.read_csv("nfl-scores-and-betting-data/nfl_teams.csv")

# replace blank cells with NaN
data = data.replace(r'^\s*$', np.nan, regex=True)

# Only need data points with over/under and spread
data = data[(data.over_under_line.isnull() == False) & (data.spread_favorite.isnull() == False)]

#realign indicies after gleaning
data.reset_index(drop=True, inplace=True)

#Convert the over under stat to float
data['over_under_line'] = data.over_under_line.astype(float)

# Use team_id from teams for usability
data['team_home'] = data.team_home.map(teams.set_index('team_name')['team_id'].to_dict())
data['team_away'] = data.team_away.map(teams.set_index('team_name')['team_id'].to_dict())

# removing extra columns 
data = data[['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
       'team_away', 'team_favorite_id', 'spread_favorite',
       'over_under_line', 'score_home', 'score_away',
       'stadium_neutral']]

#Home and away favorites to determine favorite results
data['home_fav'] = (data.team_home == data.team_favorite_id).astype(int)
data['away_fav'] = (data.team_away == data.team_favorite_id).astype(int)

#Create a result array for wins and losses based on Home team favoritism
data['result'] = (data.score_home > data.score_away).astype(int)

# %% [markdown]
# ### Part 3 *(Explore data)*

# %%
data[50:60]
# Out:
#    schedule_date  schedule_season schedule_week team_home team_away  \
# 50    09/16/1979             1979             3       LAC       BUF
# 51    09/16/1979             1979             3       SEA       OAK
# 52    09/16/1979             1979             3       ARI       PIT
# 53    09/17/1979             1979             3       WAS       NYG
# 54    09/23/1979             1979             4       BUF       NYJ
# 55    09/23/1979             1979             4       CIN       TEN
# 56    09/23/1979             1979             4       DEN       SEA
# 57    09/23/1979             1979             4       DET       ATL
# 58    09/23/1979             1979             4        KC       OAK
# 59    09/23/1979             1979             4       MIA       CHI
#
#    team_favorite_id  spread_favorite  over_under_line  score_home  score_away  \
# 50              LAC             -9.0             44.0        27.0        19.0
# 51              SEA             -3.0             44.0        27.0        10.0
# 52              PIT             -6.0             40.0        21.0        24.0
# 53              WAS             -6.0             37.0        27.0         0.0
# 54              BUF             -3.0             42.0        46.0        31.0
# 55              TEN             -3.0             37.0        27.0        30.0
# 56              DEN             -6.0             37.0        37.0        34.0
# 57              ATL             -6.0             37.0        24.0        23.0
# 58              OAK             -3.0             41.0        35.0         7.0
# 59              MIA             -6.0             37.0        31.0        16.0
#
#     stadium_neutral  home_fav  away_fav  result
# 50            False         1         0       1
# 51            False         1         0       1
# 52            False         0         1       0
# 53            False         1         0       1
# 54            False         1         0       1
# 55            False         0         1       0
# 56            False         1         0       1
# 57            False         0         1       1
# 58            False         0         1       1
# 59            False         1         0       1

# %%
data.shape
# Out:
# (9860, 14)

# %%
data.describe().round(2)
# Out:
#        schedule_season  spread_favorite  over_under_line  score_home  \
# count          9860.00          9860.00          9860.00     9860.00
# mean           1999.46            -5.37            41.84       22.64
# std              11.41             3.42             4.67       10.40
# min            1967.00           -26.50            28.00        0.00
# 25%            1990.00            -7.00            38.00       16.00
# 50%            2000.00            -4.50            41.50       22.00
# 75%            2009.00            -3.00            45.00       30.00
# max            2018.00             0.00            63.50       62.00
#
#        score_away  home_fav  away_fav   result
# count     9860.00   9860.00   9860.00  9860.00
# mean        19.83      0.67      0.32     0.58
# std         10.03      0.47      0.46     0.49
# min          0.00      0.00      0.00     0.00
# 25%         13.00      0.00      0.00     0.00
# 50%         20.00      1.00      0.00     1.00
# 75%         27.00      1.00      1.00     1.00
# max         59.00      1.00      1.00     1.00

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col4 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col5 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col6 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col7 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow0_col8 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow1_col8 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col3 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col6 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow2_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col1 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col4 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col5 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col6 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col7 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow3_col8 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col5 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col7 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col0 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col1 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col3 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col4 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col7 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow5_col8 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_474ada12_f915_11e9_abb2_685b35d4333arow6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;

# %%
win_percentage = round(sum(data.result)/len(data.result),2)
fav_percentage = sum(((data.home_fav == 1) & (data.result == 1)) | ((data.away_fav == 1) & (data.result == 0))) / len(data.result)

print("Home win percentage = %{}".format(round(win_percentage*100, 2)))
print("Away win percentage = %{}".format(round((1 - win_percentage)*100, 2)))
print("Favored win percentage = %{}".format(round((fav_percentage)*100, 2)))
# Out:
# Home win percentage = %58.0
# Away win percentage = %42.0
# Favored win percentage = %65.16

# %% [markdown]
# ### Part 4 *(Classify and predict)*

# %%
X = data[['over_under_line','spread_favorite','home_fav']]
y = data['result']

X_train, X_test, y_train, y_test = train_test_split(X, y, 0.6, 0.4 random_state=1)
classifier = DecisionTreeClassifier(min_samples_split=2)

classifier.fit(X_train,y_train)
y_predict = classifier.predict(X_test)
accuracy_score(y_test, y_predict)

pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Loss', 'Predicted Win'],
    index=['True Loss', 'True Win']
)
# Out:
#            Predicted Loss  Predicted Win
# True Loss             538            473
# True Win              530            924
