# %% [markdown]
# # CS 254 Machine Learning Final Project
#
# We will be using the ***NFL scores and betting data*** dataset to analyze successful betting techniques and winning strategies.
#
# ### Overview
#
# 1. Import packages
# 2. Wrangle and clean
# 3. Explore data
# 4. Classify and predict
# ---

# %% [markdown]
# ### Part 1 (Import Packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#List of imports will get longer

# %% [markdown]
# ### Part 2 *(Wrangle and clean)*

# %%
data = pd.read_csv("nfl-scores-and-betting-data/spreadspoke_scores.csv")
teams = pd.read_csv("nfl-scores-and-betting-data/nfl_teams.csv")

# replace blank cells with NaN
data = data.replace(r'^\s*$', np.nan, regex=True)

# Only need data points with over/under and spread
data = data[(data.over_under_line.isnull() == False) & (data.spread_favorite.isnull() == False)]

#realign indicies after gleaning
data.reset_index(drop=True, inplace=True)

#Convert the over under stat to float
data['over_under_line'] = data.over_under_line.astype(float)

# Use team_id from teams for usability
data['team_home'] = data.team_home.map(teams.set_index('team_name')['team_id'].to_dict())
data['team_away'] = data.team_away.map(teams.set_index('team_name')['team_id'].to_dict())

# removing extra columns 
data = data[['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
       'team_away', 'team_favorite_id', 'spread_favorite',
       'over_under_line', 'score_home', 'score_away',
       'stadium_neutral']]

#Home and away favorites to determine favorite results
data['home_fav'] = (data.team_home == data.team_favorite_id).astype(int)
data['away_fav'] = (data.team_away == data.team_favorite_id).astype(int)

#Create a result array for wins and losses based on Home team favoritism
data['result'] = (data.score_home > data.score_away).astype(int)

# %% [markdown]
# ### Part 2 *(Explore data)*

# %%
data[50:60]
# Out:
#    schedule_date  schedule_season schedule_week team_home team_away  \
# 50    09/23/1979             1979             4       NYG       PHI
# 51    09/23/1979             1979             4       PIT       IND
# 52    09/23/1979             1979             4        SF        NO
# 53    09/23/1979             1979             4       ARI       WAS
# 54    09/23/1979             1979             4        TB       LAR
# 55    09/24/1979             1979             4       CLE       DAL
# 56    09/30/1979             1979             5       ATL       WAS
# 57    09/30/1979             1979             5       IND       BUF
# 58    09/30/1979             1979             5       CHI        TB
# 59    09/30/1979             1979             5       DAL       CIN
#
#    team_favorite_id  spread_favorite  over_under_line  score_home  score_away  \
# 50              PHI             -5.0             37.0        13.0        17.0
# 51              PIT            -14.0             38.0        17.0        13.0
# 52             PICK              0.0             42.0        21.0        30.0
# 53              ARI             -3.0             39.0         7.0        17.0
# 54              LAR             -3.0             35.0        21.0         6.0
# 55              DAL             -3.0             40.0        26.0         7.0
# 56              ATL             -3.0             37.0         7.0        16.0
# 57              IND             -2.0             42.0        13.0        31.0
# 58              CHI             -1.0             34.0        13.0        17.0
# 59              DAL            -10.0             40.0        38.0        13.0
#
#     stadium_neutral  home_fav  away_fav  result
# 50            False         0         1       0
# 51            False         1         0       1
# 52            False         0         0       0
# 53            False         1         0       0
# 54            False         0         1       1
# 55            False         0         1       1
# 56            False         1         0       0
# 57            False         1         0       0
# 58            False         1         0       0
# 59            False         1         0       1

# %%
data.shape
# Out:
# (9848, 14)

# %%
data.describe().round(2)
# Out:
#        schedule_season  spread_favorite  over_under_line  score_home  \
# count          9848.00          9848.00          9848.00     9848.00
# mean           1999.49            -5.37            41.85       22.65
# std              11.37             3.42             4.67       10.40
# min            1979.00           -26.50            28.00        0.00
# 25%            1990.00            -7.00            38.00       16.00
# 50%            2000.00            -4.50            41.50       22.00
# 75%            2009.00            -3.00            45.00       30.00
# max            2018.00             0.00            63.50       62.00
#
#        score_away  home_fav  away_fav   result
# count     9848.00   9848.00   9848.00  9848.00
# mean        19.84      0.67      0.32     0.58
# std         10.03      0.47      0.46     0.49
# min          0.00      0.00      0.00     0.00
# 25%         13.00      0.00      0.00     0.00
# 50%         20.00      1.00      0.00     1.00
# 75%         27.00      1.00      1.00     1.00
# max         59.00      1.00      1.00     1.00

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col4 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col6 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col7 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow0_col8 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col5 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow1_col8 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col3 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col6 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow2_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col1 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col4 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col6 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col7 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow3_col8 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col7 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col1 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col4 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col7 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow5_col8 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_f91ef62c_f8d1_11e9_802a_685b35d4333arow6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;

# %%
win_percentage = round(sum(data.result)/len(data.result),2)
fav_percentage = sum(((df.home_favorite == 1) & (df.result == 1)) | ((df.away_favorite == 1) & (df.result == 0))) / len(data.result)

print("Home win percentage = %{}".format(round(win_percentage*100, 2)))
print("Away win percentage = %{}".format(round((1 - win_percentage)*100, 2)))
print("Favored win percentage = %{}".format(round((fav_percentage)*100, 2)))
# Out:
# Home win percentage = %58.0
# Away win percentage = %42.0
# Favored win percentage = %77.1
